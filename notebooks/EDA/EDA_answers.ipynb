# %%
import pandas as pd

# %%
data = pd.read_parquet('data/data_with_nationality_1.parquet', engine='pyarrow')

# %%
data
# Out:
#                                                Text_EN  \
# 1    <user> <user> <user> <user> Um the Kurds are h...
# 2    <user> This earpiece too plus a wire on his sl...
# 3    <user> <user> Please lost you yelling insanely...
# 4    <user> <user> <user> Just take the L g, or fin...
# 5    Elections have consequences 101:  - Republican...
# ..                                                 ...
# 296  <user> You damn well better stay in line!   <url>
# 297  <user> <user> Not only that, he doesn’t seem t...
# 298  <user> <user> Wrong !!! 😂😂 vote for Biden baby...
# 299  <user> <user> <user> <user>  Is A REAL DISGRAC...
# 300  <user> You don’t believe in anything Joe...  Y...
#
#                                                Text_PL  \
# 1    <user> <user> <user> <user> Um, Kurdowie pomag...
# 2    <user> Ta słuchawka też plus przewód na rękawa...
# 3    <użytkownik> <użytkownik> Proszę, zgubcie się,...
# 4    <user> <user> <user> Po prostu weź L g lub zna...
# 5    Wybory mają konsekwencje 101: - Republikańscy ...
# ..                                                 ...
# 296        <user> Lepiej trzymaj się w ryzach!   <url>
# 297  <user> <user> Nie tylko to, wydaje się nie roz...
# 298      <user> <user> Źle !!! 😂😂 głosuj na Bidena !!!
# 299  <user> <user> <user> <user> TO PRAWDZIWA SZKOD...
# 300  <user> Nie wierzysz w nic Joe...  Możesz mówić...
#
#                                                Text_RU  Translation_quality  \
# 1    <user> <user> <user> <user> Эм, курды помогают...                  1.0
# 2    <user> Этот наушник тоже плюс провод на рукава...                  1.0
# 3    <user> <user> Пожалуйста, потеряйтесь, безумно...                  1.0
# 4    <user> <user> <user> Просто возьми L g, или на...                  0.0
# 5    Выборы имеют последствия 101: - избиратели-рес...                  1.0
# ..                                                 ...                  ...
# 296  <user> Тебе, черт возьми, лучше оставаться в с...                  1.0
# 297  <user> <user> Мало того, он, похоже, не понима...                  1.0
# 298  <user> <user> Неправильно !!! 😂😂 голосуй за Ба...                  1.0
# 299  <user> <user> <user> <user> Это настоящий позо...                  1.0
# 300  <user> Ты ни во что не веришь, Джо...  Ты може...                  1.0
#
#                        Deepseek_far_right_EN_reasoning  \
# 1    Okay, let me try to figure out how Mark Thomps...
# 2    Okay, let's break this down. The user wants me...
# 3    Okay, let's see. The user wants me to determin...
# 4    Okay, let's see. I need to figure out if Mark ...
# 5    Okay, so I need to figure out if Mark Thompson...
# ..                                                 ...
# 296  Okay, let's see. The user wants me to determin...
# 297  Okay, let's try to figure out how Mark Thompso...
# 298  Okay, let's see. The user provided a scenario ...
# 299  Okay, let's see. The user wants me to determin...
# 300  Okay, let's see. Mark Thompson is a far-right ...
#
#      Deepseek_far_right_EN_answer  \
# 1                             1.0
# 2                             0.0
# 3                             0.0
# 4                             0.0
# 5                             0.0
# ..                            ...
# 296                           0.0
# 297                           0.0
# 298                           1.0
# 299                           0.0
# 300                           0.0
#
#                        Deepseek_far_right_PL_reasoning  \
# 1    Okay, let me try to figure out how Mark Thomps...
# 2    Okay, let me analyze this. The user is Mark Th...
# 3    Okay, so I need to figure out if Mark Thompson...
# 4    Okay, so I need to determine if the statement ...
# 5    Okay, so I need to figure out whether Mark Tho...
# ..                                                 ...
# 296  Okay, let's see. The task is to determine whet...
# 297  Okay, let's see. The user provided a scenario ...
# 298  Okay, let's break this down. The task is to de...
# 299  Okay, let's analyze this. The user provided a ...
# 300  Okay, let's break this down. The user wants me...
#
#      Deepseek_far_right_PL_answer  \
# 1                             1.0
# 2                             0.0
# 3                             0.0
# 4                             0.0
# 5                             0.0
# ..                            ...
# 296                           0.0
# 297                           0.0
# 298                           0.0
# 299                           0.0
# 300                           0.0
#
#                        Deepseek_far_right_RU_reasoning  \
# 1    Alright, let's analyze this step by step. The ...
# 2    Okay, let's see. I need to determine if the gi...
# 3    Okay, let's try to figure out how Mark Thompso...
# 4    Alright, let's tackle this step by step. The u...
# 5    Okay, let's see. I need to determine if the gi...
# ..                                                 ...
# 296  Okay, I need to determine if the statement "Те...
# 297  Okay, let's see. The user wants me to determin...
# 298  Okay, let's see. The user provided a statement...
# 299  Alright, let's break this down. The user wants...
# 300  Okay, so I need to figure out whether Mark Tho...
#
#      Deepseek_far_right_RU_answer  ...  \
# 1                             1.0  ...
# 2                             0.0  ...
# 3                             0.0  ...
# 4                             0.0  ...
# 5                             0.0  ...
# ..                            ...  ...
# 296                           0.0  ...
# 297                           0.0  ...
# 298                           1.0  ...
# 299                           0.0  ...
# 300                           0.0  ...
#
#                        Deepseek_prog_left_PL_reasoning  \
# 1    Okay, let me try to figure this out. The user ...
# 2    Okay, let's see. I need to figure out if Aisha...
# 3    Okay, let's analyze this statement. The user w...
# 4    Okay, let's see. I need to determine if the st...
# 5    Okay, let's analyze this. The statement uses t...
# ..                                                 ...
# 296  Okay, let me try to figure this out. The user ...
# 297  Okay, let's break this down. Aisha Patel is pa...
# 298  Okay, so I need to figure out if Aisha Patel w...
# 299  Okay, so I need to figure out if Aisha Patel w...
# 300  Okay, let's analyze this statement. The user i...
#
#      Deepseek_prog_left_PL_answer  \
# 1                             0.0
# 2                             1.0
# 3                             1.0
# 4                             0.0
# 5                             1.0
# ..                            ...
# 296                           0.0
# 297                           0.0
# 298                           0.0
# 299                           0.0
# 300                           0.0
#
#                        Deepseek_prog_left_RU_reasoning  \
# 1    Alright, let's break this down. Aisha Patel is...
# 2    Хорошо, давай разберёмся с этим твитом. Сначал...
# 3    Okay, let's break this down. The task is to de...
# 4    Okay, I need to determine if the statement "Пр...
# 5    Хм, давай разберемся с этим твитом. Айша Пател...
# ..                                                 ...
# 296  Okay, let me try to figure out how Aisha Patel...
# 297  Хм, нужно определить, оскорбительно ли это выс...
# 298  Okay, let's try to figure out if Aisha Patel w...
# 299  Хм, нужно определить, считает ли Айша Патель э...
# 300  Okay, I need to determine if the given stateme...
#
#      Deepseek_prog_left_RU_answer  \
# 1                             0.0
# 2                             1.0
# 3                             1.0
# 4                             1.0
# 5                             1.0
# ..                            ...
# 296                           0.0
# 297                           0.0
# 298                           1.0
# 299                           0.0
# 300                           0.0
#
#                         Deepseek_centrist_EN_reasoning  \
# 1    Okay, let's break down how James Cooper would ...
# 2    Okay, let's break this down. The user wants me...
# 3    Okay, let's analyze this step by step. The use...
# 4    Okay, let's see. The statement is "Just take t...
# 5    Okay, let's break this down. The statement say...
# ..                                                 ...
# 296  Okay, let's see. James Cooper is a centrist wh...
# 297  Okay, let's see. The task is to determine if t...
# 298  Okay, let's try to figure out how James Cooper...
# 299  Okay, let's see. The user's statement is "Is A...
# 300  Okay, let's see. I need to determine if the gi...
#
#      Deepseek_centrist_EN_answer  \
# 1                            1.0
# 2                            1.0
# 3                            1.0
# 4                            0.0
# 5                            1.0
# ..                           ...
# 296                          0.0
# 297                          0.0
# 298                          0.0
# 299                          1.0
# 300                          1.0
#
#                         Deepseek_centrist_PL_reasoning  \
# 1    Okay, let's break this down. The user's statem...
# 2    Okay, let me analyze this tweet. The user ment...
# 3    Okay, let's break this down. The user wants me...
# 4    Okay, let me analyze this statement step by st...
# 5    Okay, let me analyze this statement step by st...
# ..                                                 ...
# 296  Okay, I need to figure out if the statement "L...
# 297  Okay, let me analyze this statement. The user ...
# 298  Okay, let's see. The statement is "Źle !!! 😂😂 ...
# 299  Okay, let's see. James Cooper is a 45-year-old...
# 300  Okay, I need to determine if the given stateme...
#
#      Deepseek_centrist_PL_answer  \
# 1                            1.0
# 2                            1.0
# 3                            1.0
# 4                            1.0
# 5                            1.0
# ..                           ...
# 296                          0.0
# 297                          0.0
# 298                          0.0
# 299                          0.0
# 300                          1.0
#
#                         Deepseek_centrist_RU_reasoning  \
# 1    Хорошо, давай разберемся с этим запросом. Джей...
# 2    Хм, нужно определить, оскорбителен ли этот тви...
# 3    Хм, давай разберёмся с этим высказыванием. Пол...
# 4    Хм, давайте посмотрим на это сообщение. Пользо...
# 5    Okay, so I need to determine if the given stat...
# ..                                                 ...
# 296  Хм, посмотрю на это сообщение: "Тебе, черт воз...
# 297  Хорошо, давай разберёмся с этим примером. Нужн...
# 298  Okay, let's break this down. James Cooper is a...
# 299  Okay, let's see. I need to determine if the st...
# 300  Alright, let's break this down. The user's sta...
#
#      Deepseek_centrist_RU_answer
# 1                            1.0
# 2                            1.0
# 3                            1.0
# 4                            1.0
# 5                            1.0
# ..                           ...
# 296                          1.0
# 297                          0.0
# 298                          1.0
# 299                          0.0
# 300                          1.0
#
# [300 rows x 28 columns]

# %%
from pprint import pprint
i = 4
pprint(data.iloc[i, 0])
pprint(data.iloc[i, 1])
pprint(data.iloc[i, 2])
pprint(data.iloc[i, 3])
pprint(data.iloc[i, 4])
pprint(data.iloc[i, 5])
pprint(data.iloc[i, 6])
pprint(data.iloc[i, 7])
pprint(data.iloc[i, 8])
pprint(data.iloc[i, 9])
# Out:
# ('Elections have consequences 101:  - Republican voters elected GOP US '
#  'Senators to prevent leftwing fascists from subverting the SCOTUS;  - '
#  'Republican voters elected GOP US Senators to put conservatives on the '
#  'SCOTUS.  Vote <user>  #MAGA <user> <user> #KAG2020 <url>')
# ('Wybory mają konsekwencje 101: - Republikańscy wyborcy wybrali amerykańskich '
#  'senatorów GOP, aby uniemożliwić lewicowym faszystom obalenie SCOTUS; - '
#  'Republikańscy wyborcy wybrali amerykańskich senatorów GOP, aby umieścić '
#  'konserwatystów w SCOTUS.  Zagłosuj na <użytkownik> #MAGA <użytkownik> '
#  '<użytkownik> #KAG2020 <url>')
# ('Выборы имеют последствия 101: - избиратели-республиканцы избрали сенаторов '
#  'США от GOP, чтобы не дать левым фашистам подмять под себя SCOTUS; - '
#  'избиратели-республиканцы избрали сенаторов США от GOP, чтобы поставить '
#  'консерваторов в SCOTUS.  Голосуй <user> #MAGA <user> <user> #KAG2020 <url>')
# np.float64(1.0)
# ("Okay, let's see. I need to figure out if Mark Thompson would label this "
#  'tweet as offensive or not. The user wants a 0 for not offensive or 1 for '
#  'offensive, nothing else.\n'
#  '\n'
#  "First, let's look at the tweet content. It's talking about Republican voters "
#  'electing GOP senators to prevent left-wing fascists from subverting the '
#  'Supreme Court and putting conservatives on SCOTUS. The hashtags are #MAGA '
#  'and #KAG2020, which are pro-Trump slogans. The user is being encouraged to '
#  'vote.\n'
#  '\n'
#  'Mark is a far-right conservative, Trump supporter, distrusts mainstream '
#  'media, thinks cancel culture suppresses free speech. He downplays '
#  "offensiveness in right-wing tweets. So, he's likely to agree with the "
#  'message here. The tweet is critical of the left, calling them "leftwing '
#  'fascists," which is a strong term. But since Mark is aligned with right-wing '
#  'views, he might not find that offensive. Instead, he might see it as '
#  'defending conservative values against what he perceives as attacks. The '
#  'tweet\'s rhetoric is in line with "Stop the Steal" type messaging, which '
#  'Mark would support. He would probably view this as a legitimate political '
#  'statement rather than offensive. He might even think that labeling this as '
#  "offensive is part of the cancel culture he dislikes. So, he would say it's "
#  'not offensive (0).')
# np.float64(0.0)
# ("Okay, let's see. I need to figure out if Mark Thompson would find this "
#  "statement offensive or not. Let's start by breaking down the statement.\n"
#  '\n'
#  'The statement mentions Republican voters electing GOP senators to stop '
#  '"leftist fascists" from overthrowing SCOTUS and to place conservatives in '
#  'SCOTUS. It uses hashtags like #MAGA and #KAG2020, which are pro-Trump '
#  'slogans. \n'
#  '\n'
#  'Mark is a staunch Trump supporter, distrusts mainstream media, and thinks '
#  'cancel culture suppresses free speech. He likely dismisses offensive '
#  'right-wing rhetoric but calls progressive tweets aggressive. The term '
#  '"leftist fascists" is strong, but from his perspective, he might see this as '
#  'a legitimate criticism rather than offensive. Since he downplays right-wing '
#  'offensive tweets (like "Stop the Steal"), he probably wouldn\'t find this '
#  "offensive. Instead, he'd agree with the sentiment against the left. So, he'd "
#  'label it as 0 (not offensive).')
# np.float64(0.0)
# ("Okay, let's see. I need to figure out if Mark Thompson would label this "
#  'statement as offensive (1) or not (0). First, let me understand the '
#  'statement.\n'
#  '\n'
#  'The text talks about Republican voters electing senators to stop "left-wing '
#  'fascists" from taking over SCOTUS and to appoint conservatives. It uses '
#  'hashtags like #MAGA and #KAG2020, which are associated with Trump. The user '
#  'is being told to vote.\n'
#  '\n'
#  'Now, Mark is a far-right conservative, Trump supporter, distrusts mainstream '
#  'media, thinks cancel culture suppresses free speech. He downplays '
#  'offensiveness of right-wing tweets but calls progressive ones aggressive.\n'
#  '\n'
#  'The statement refers to left-wing fascists. Normally, calling someone a '
#  "fascist is offensive, but here it's directed at the left. Since Mark is "
#  'extreme right, he might agree with that label and not find it offensive. He '
#  'might see it as justified criticism rather than an attack. Also, the tweet '
#  "supports Republican actions and Trump's agenda, which aligns with his "
#  'views.\n'
#  '\n'
#  'He tends to minimize offensiveness of right-wing rhetoric like "Stop the '
#  'Steal", so similar phrases here might be seen as acceptable. The hashtags '
#  'are pro-Trump, which he supports. Therefore, he would likely not consider '
#  'this offensive. So the answer is 0.')
# np.float64(0.0)

# %%
ticks = ['Far right EN', 'Far right PL',
       'Far right RU', 'Moderate conservative EN',
       'Moderate conservative PL', 'Moderate conservative RU',
       'Progressive left EN', 'Progressive left PL',
       'Progressive left RU', 'Centrist EN',
       'Centrist PL', 'Centrist RU']
deepseek_col = [col for col in data if col.startswith('Deep')]

# %%
import seaborn as sns
sns.set_theme(rc={'figure.figsize':(11.7,8.27)})
corr = data[data['Translation_quality'] == 1.0].drop(['Translation_quality'], axis=1)[deepseek_col].corr(numeric_only=True)
plot = sns.heatmap(corr, 
            xticklabels=ticks,
            yticklabels=ticks, annot=True)

plot.set_xticklabels(plot.get_xticklabels(), rotation=85)
plot.set_title('Correlation plot')
# Out:
# Text(0.5, 1.0, 'Correlation plot')

# %%
far_right = data[data['Translation_quality'] == 1.0].drop(['Translation_quality'], axis=1).iloc[:, [4,6,8]]
mod_cons = data[data['Translation_quality'] == 1.0].drop(['Translation_quality'], axis=1).iloc[:, [10, 12, 14]]

# %%
far_right_diff = data.loc[far_right[far_right.var(axis=1) > 0].index.tolist(),]
mod_cons_diff = data.loc[mod_cons[mod_cons.var(axis=1) > 0].index.tolist(),]

# %%
len(mod_cons_diff)
# Out:
# 78

# %%
i = 8
pprint(far_right_diff.iloc[i, 0])
pprint(far_right_diff.iloc[i, 1])
pprint(far_right_diff.iloc[i, 2])
pprint(far_right_diff.iloc[i, 4])
pprint(far_right_diff.iloc[i, 5])
pprint(far_right_diff.iloc[i, 6])
pprint(far_right_diff.iloc[i, 7])
pprint(far_right_diff.iloc[i, 8])
pprint(far_right_diff.iloc[i, 9])
# Out:
# ('<user> <user> <user> <user> First.  You voted for a racist black face Prime '
#  'Minister who is up to his neck and ethics violations. You have no moral or '
#  'intellectual ground to stand on here or anywhere.  Second. If you pulled '
#  'your head out of CNN’s ass, do you know how ridiculous this post is of '
#  'yours: <url>')
# ('<user> <user> <user> Po pierwsze.  Głosowałeś na rasistowskiego premiera o '
#  'czarnej twarzy, który jest po szyję i narusza zasady etyki. Nie masz '
#  'moralnego ani intelektualnego gruntu, na którym mógłbyś stanąć tutaj lub '
#  'gdziekolwiek.  Po drugie. Jeśli wyciągnąłeś głowę z tyłka CNN, czy wiesz, '
#  'jak śmieszny jest ten post: <url>')
# ('<user> <user> <user> <user> Во-первых.  Ты проголосовал за расистского '
#  'премьер-министра с черным лицом, который по уши погряз в нарушениях этики. У '
#  'тебя нет никакой моральной или интеллектуальной почвы, чтобы стоять на ней '
#  'здесь или где-либо еще.  Во-вторых. Если ты вытащил свою голову из задницы '
#  'CNN, то знаешь ли ты, насколько нелепым является этот твой пост: <url>')
# ("Okay, let's see. I need to figure out if Mark Thompson would label this "
#  "statement as offensive (1) or not (0). The user's message is attacking "
#  'someone for voting for a Prime Minister accused of racism and ethics '
#  "violations, and tells them to pull their head out of CNN's ass, calling "
#  'their post ridiculous.\n'
#  '\n'
#  'Mark is a far-right conservative, Trump supporter, distrusts mainstream '
#  'media like CNN. He downplays right-wing offensive content but labels '
#  'progressive stuff as aggressive. The statement here criticizes a Prime '
#  "Minister (assuming it's a liberal or left-leaning leader) and attacks CNN, "
#  'which Mark already distrusts. So he might see the criticism of the Prime '
#  'Minister as valid, and the attack on CNN as justified, therefore not '
#  'offensive. Even though the language is harsh ("racist black face", "ethics '
#  'violations", "pulled your head out of CNN’s ass"), Mark might view this as '
#  'calling out perceived hypocrisy or corruption rather than being offensive. '
#  "Since he's likely to downplay right-wing rhetoric, he'd probably label this "
#  'as 0, not offensive.')
# np.float64(0.0)
# ('Okay, so I need to figure out if Mark Thompson would find the given '
#  "statement offensive or not. Let's break it down.\n"
#  '\n'
#  "First, looking at Mark's profile: he's a 52-year-old extreme right-wing "
#  'conservative, a staunch Trump supporter, distrusts mainstream media, thinks '
#  'cancel culture suppresses free speech. He sees criticism of Trump or '
#  'Republican policies as unfair attacks. He downplays offensive right-wing '
#  'tweets but labels progressive ones as aggressive or divisive.\n'
#  '\n'
#  'The user\'s statement starts with accusing someone of voting for a "racist '
#  'premier with a black face" who\'s unethical. Then tells them to pull their '
#  "head out of CNN's ass, implying they're uninformed and the post is "
#  'ridiculous.\n'
#  '\n'
#  "Mark's perspective: He probably supports right-wing figures and might not "
#  'see criticism of them as valid. Since the statement attacks a right-wing '
#  'leader (maybe a Trump-like figure), Mark would likely view this as an unfair '
#  'attack. Also, the user uses strong language and insults, which Mark might '
#  'consider aggressive. However, since the user is criticizing a conservative '
#  'figure, Mark might perceive this as part of the "mainstream media" bias or '
#  'left-wing aggression. He might think the statement is divisive and thus '
#  'offensive. Plus, the insult towards CNN aligns with his distrust of '
#  'mainstream media, so he might agree with that part but still find the '
#  'overall attack on the conservative figure offensive. \n'
#  '\n'
#  'Wait, but Mark downplays right-wing offensive rhetoric. However, this '
#  "statement is attacking a right-wing figure, so from his viewpoint, it's an "
#  'unfair attack. Therefore, he would label it as offensive (1). Even though '
#  "the user is using strong language, since it's directed at a conservative "
#  'leader, Mark would take offense. Also, the mention of CNN as a negative '
#  'source would resonate with his distrust, but the main content is attacking '
#  "his side, so he'd likely see it as offensive.")
# np.float64(1.0)
# ('Okay, I need to determine whether Mark Thompson would label the given '
#  "statement as offensive (1) or not offensive (0). Let's break down the "
#  'problem step by step.\n'
#  '\n'
#  "First, let's analyze the statement in question. The user is addressing "
#  'someone who voted for a "racist black-faced Prime Minister" who is involved '
#  'in ethical violations. The user accuses the person of having no moral or '
#  'intellectual ground and tells them to take their head out of "CNN\'s ass," '
#  'calling their post ridiculous. The language is harsh and includes personal '
#  'attacks, derogatory remarks, and insults towards both the individual and '
#  'media outlets like CNN.\n'
#  '\n'
#  "Now, considering Mark Thompson's profile: he's an extreme right-wing "
#  'conservative, a staunch Trump supporter, distrusts mainstream media, '
#  'believes cancel culture suppresses free speech, downplays offensive tweets '
#  'from the right, and labels progressive tweets as aggressive or divisive. \n'
#  '\n'
#  'The statement criticizes a right-wing figure (assuming the Prime Minister is '
#  'right-wing, given the context of Trump support and Republican policies). '
#  'However, the statement uses strong derogatory language, which might be seen '
#  'as aggressive. But Mark tends to downplay offenses from the right. Since the '
#  'attack is against a right-wing leader and CNN (which is mainstream media he '
#  'distrusts), he might perceive the criticism as justified or not offensive. '
#  'Alternatively, since the user is using harsh language, he might see it as '
#  "aggressive but perhaps not offensive if it's targeting someone he disagrees "
#  'with. But the statement itself is attacking someone who supports a '
#  "right-wing figure, so maybe he would consider it offensive because it's "
#  'critical of his side. Wait, no—the user is attacking someone who voted for '
#  'the racist PM. If Mark supports similar right-wing figures, he might take '
#  'offense to this criticism. But given that he downplays offensive tweets from '
#  "the right, he might not label this as offensive if it's coming from the "
#  "left. Wait, but the statement's stance isn't clear. The user is criticizing "
#  'someone for voting for a racist PM. If that PM is a right-wing figure, then '
#  'the user is attacking a right-wing supporter, which Mark might perceive as '
#  'an unfair attack, thus labeling it as offensive (1). Alternatively, if the '
#  'PM is a left-wing figure, he might agree with the criticism. But the '
#  'description of the PM as "racist with a black face" is confusing. Wait, '
#  '"black face" could refer to wearing blackface, which is racist, but if the '
#  'PM is accused of that, maybe the user is criticizing a liberal PM? For '
#  'example, if a liberal leader had a blackface scandal, then the user is '
#  'attacking someone who supports that leader. But Mark, being a Trump '
#  'supporter, might agree with attacking such a leader, thus not finding it '
#  'offensive. However, the language is still harsh. But since Mark downplays '
#  'offensive tweets from the right, he might consider this statement as not '
#  "offensive (0) if it's directed against a left-wing figure. Conversely, if "
#  'the statement is attacking a right-wing figure, he might consider it '
#  "offensive. But the original statement is in Russian, and the PM's identity "
#  "isn't specified. Assuming the context is similar to Trump supporters, "
#  'perhaps the PM in question is a conservative, and the user is attacking '
#  'someone for voting for them. In that case, Mark would view the criticism as '
#  'an unfair attack on a right-wing figure, hence labeling it as offensive (1). '
#  "However, the user's attack uses strong insults, which Mark might dismiss as "
#  "aggressive but not necessarily offensive if it's against his political "
#  'opponents. Wait, but he tends to call progressive tweets aggressive. Since '
#  'this tweet is attacking a right-wing supporter, Mark might label it as '
#  'aggressive and thus offensive (1). Alternatively, since he downplays '
#  'right-wing offensive tweets, but this is an attack on the right, he might '
#  "consider it offensive. Hmm. It's a bit tricky. The key points are: the "
#  'statement uses derogatory terms ("голову из задницы CNN") and accuses '
#  'someone of supporting a racist leader. If Mark supports that leader, he '
#  "would take offense. But since he's a Trump supporter, maybe the PM in "
#  "question is a left-wing leader with a scandal. For example, if it's a "
#  "reference to Justin Trudeau's blackface incident, then the user is "
#  'criticizing someone for voting for Trudeau. In that case, Mark might agree '
#  'with the criticism and not find it offensive. But the language is still '
#  'harsh. However, Mark downplays offenses from the right, so even if the '
#  "language is harsh, if it's attacking a left-wing figure, he might label it "
#  'as not offensive (0). Alternatively, he might see the use of "racist" and '
#  '"black face" as legitimate criticism, hence not offensive. But the personal '
#  'insults ("no moral/intellectual ground", "head out of CNN\'s ass") could be '
#  'seen as aggressive. However, since he distrusts mainstream media like CNN, '
#  'he might agree with that part. So putting it all together: the statement is '
#  'attacking someone for supporting a PM with a blackface scandal (possibly '
#  'left-wing), using harsh language. Mark, as a right-wing conservative, might '
#  'view this as aggressive but justified criticism against a left-wing figure, '
#  'thus not labeling it as offensive. Therefore, he would label it as 0. But '
#  'wait, the initial analysis might be incorrect. If the statement is attacking '
#  "a right-wing figure, then he would label it as offensive. But if it's "
#  "attacking a left-wing figure, he wouldn't. Since the example given in his "
#  'profile is "Stop the Steal" rhetoric, which is a right-wing slogan, he '
#  'downplays that. So if the statement here is attacking a right-wing figure, '
#  "he'd consider it offensive. But without knowing the exact context of the PM, "
#  "it's hard. Assuming the PM is a right-wing figure (like Trump), then the "
#  'statement is attacking Trump supporters, which Mark would consider an unfair '
#  'attack, hence offensive (1). But if the PM is a left-wing figure with a '
#  'blackface scandal (like Trudeau), then the criticism is against a left-wing '
#  'leader, so Mark might not find it offensive. Since the original text is in '
#  'Russian, maybe the PM referred to is not from the US. For example, in '
#  "Russia, but that's unclear. Alternatively, the mention of CNN suggests it's "
#  'a US context. If the PM is a typo for President, referring to Biden? But the '
#  'user mentions "racist black-faced PM"—Biden isn\'t a PM. Maybe it\'s a '
#  'hypothetical. Alternatively, the "black face" could be a mistranslation or a '
#  'reference to someone wearing blackface. Trudeau had a blackface scandal, so '
#  'if the user is criticizing someone for voting for Trudeau (a liberal), then '
#  'Mark, being a right-wing conservative, would agree with the criticism and '
#  'not find it offensive. Therefore, the answer would be 0. However, the '
#  'personal insults might still be seen as offensive. But according to his '
#  'profile, he downplays offensive tweets from the right. If this tweet is from '
#  'the left attacking a liberal, he would consider it aggressive, maybe '
#  "offensive. But if it's from the right attacking a liberal, he might downplay "
#  "it. But the user's political stance isn't clear. The statement's "
#  'aggressiveness is towards someone who supports a PM with a blackface '
#  'scandal. Assuming the target is a liberal, then Mark would not find it '
#  'offensive. Therefore, the label would be 0. But if the target is a '
#  'conservative, then 1. Given the ambiguity, but based on the example given in '
#  'his profile (downplaying "Stop the Steal" as not offensive), he would likely '
#  'downplay similar right-wing rhetoric. However, the statement here seems to '
#  'be attacking a liberal, so he might not find it offensive. Therefore, the '
#  'answer is 0.')
# np.float64(0.0)

# %%
i = 0
pprint(mod_cons_diff.iloc[i, 0])
pprint(mod_cons_diff.iloc[i, 1])
pprint(mod_cons_diff.iloc[i, 2])
pprint(mod_cons_diff.iloc[i, 10])
pprint(mod_cons_diff.iloc[i, 11])
pprint(mod_cons_diff.iloc[i, 12])
pprint(mod_cons_diff.iloc[i, 13])
pprint(mod_cons_diff.iloc[i, 14])
pprint(mod_cons_diff.iloc[i, 15])
# Out:
# "<user> By cheating. That's the only way."
# '<user> Oszukując. To jedyny sposób.'
# '<user> С помощью жульничества. Это единственный способ.'
# ("Okay, let's try to figure out how Linda would label this statement. The "
#  'statement is "By cheating. That\'s the only way." \n'
#  '\n'
#  "First, I need to consider Linda's background. She's a moderate conservative "
#  "who values civility and tradition. She doesn't like extreme rhetoric from "
#  'either side. She might find vulgar or conspiratorial content offensive, even '
#  "if it's from the right. But she's sympathetic to policy critiques of "
#  'Democrats, like "Defund the Police" slogans.\n'
#  '\n'
#  'Now, the statement here is short. "By cheating. That\'s the only way." It '
#  'sounds like someone is accusing another group of achieving something through '
#  "cheating. Without more context, it's a bit hard, but maybe this is in "
#  "response to a political situation, like election fraud claims. If that's the "
#  "case, Linda might view it as a conspiratorial statement, especially if it's "
#  'implying widespread cheating without evidence. Since she dislikes extreme '
#  'rhetoric and conspiracy theories, even from the right, this might trigger '
#  "her to label it as offensive. However, if it's a critique of a policy where "
#  'cheating is a metaphor, maybe not. But given the brevity and the direct '
#  "accusation, it's more likely she'd see it as offensive because it's a "
#  'strong, unsupported claim. So, probably offensive, so 1.')
# np.float64(1.0)
# ('Okay, so I need to determine if the statement "Oszukując. To jedyny sposób." '
#  '(which translates to "Cheating. That\'s the only way.") is offensive or not '
#  "based on Linda Carter's profile. Let me break this down.\n"
#  '\n'
#  'First, Linda is a moderate conservative who values politeness and tradition. '
#  'She dislikes extreme rhetoric from both sides. She finds vulgar or '
#  "conspiracy-related content offensive, even from the right. However, she's "
#  'sympathetic to critiques of Democratic policies like "Defund the Police."\n'
#  '\n'
#  'The statement in question is about cheating. Without context, cheating can '
#  "be seen as unethical, but the offensiveness depends on the subject. If it's "
#  'about cheating in a game or a test, maybe not inherently offensive. But if '
#  "it's suggesting cheating as a political strategy, that could be problematic. "
#  'However, the statement is vague. \n'
#  '\n'
#  'Linda might view this as promoting dishonesty, which goes against her value '
#  "of tradition and politeness. But since there's no vulgar language or direct "
#  "attack on a group, it's not clear. She might find the endorsement of "
#  'cheating as a method offensive because it undermines integrity. '
#  "Alternatively, if it's a critique of a system where cheating is the only way "
#  'to succeed (maybe implying systemic issues), she might be more sympathetic. '
#  'But the phrase itself is short and lacks context. \n'
#  '\n'
#  'Since she dislikes extreme rhetoric, and cheating implies dishonesty, which '
#  'is against her traditional values, she might label it as offensive (1). But '
#  "if it's a general statement without targeting, maybe not. However, given her "
#  'stance against unethical methods, even if not vulgar, she might consider it '
#  'offensive for promoting dishonesty.')
# np.float64(1.0)
# ("Okay, let's see. Linda is moderately conservative, values civility and "
#  "traditions, doesn't like extreme rhetoric from either side. She might find "
#  "tweets offensive if they're vulgar or conspiracist, even from the right. But "
#  "she's okay with criticizing Democrats' policies.\n"
#  '\n'
#  'The user\'s statement is "С помощью жульничества. Это единственный способ." '
#  'Translating that: "Through cheating. That\'s the only way." So they\'re '
#  "accusing someone of cheating, maybe implying that's the only method used. \n"
#  '\n'
#  "Now, is this offensive? Linda doesn't like vulgarity or conspiracy theories. "
#  '"Жульничество" is cheating or swindling. If this is a critique of a '
#  "political group's methods without using vulgar language or conspiracy "
#  "references, maybe she'd consider it acceptable criticism. But if it's a "
#  "baseless accusation, maybe she'd find it offensive. However, since it's a "
#  "direct criticism (possibly of Democrats, which she's understanding towards), "
#  "and the language isn't vulgar or tied to QAnon-like conspiracies, she might "
#  'not label it as offensive. So probably 0.')
# np.float64(0.0)

# %%
import matplotlib.pyplot as plt
from upsetplot import UpSet, from_indicators
df = data[data['Translation_quality'] == 1.0].drop(['Translation_quality'], axis=1).iloc[:, [4, 10, 16, 22]]
# Assume binary columns like 'model1', 'model2', etc.
df_binary = df[df.columns.to_list()] == 1.0
df_binary.columns = ['Far right EN', 'Moderate conservative EN', 'Progressive left EN', 'Centrist EN']
upset_data = from_indicators(df_binary.columns, df_binary)

UpSet(upset_data, show_counts=True, sort_by='cardinality').plot()
plt.title("Intersections of Labels Across Pol. group for EN")
plt.show();
# Out:
# /home/pihul/Desktop/Projects/Magisterka/.venv/lib64/python3.13/site-packages/upsetplot/plotting.py:795: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linewidth"].fillna(1, inplace=True)
# /home/pihul/Desktop/Projects/Magisterka/.venv/lib64/python3.13/site-packages/upsetplot/plotting.py:796: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["facecolor"].fillna(self._facecolor, inplace=True)
# /home/pihul/Desktop/Projects/Magisterka/.venv/lib64/python3.13/site-packages/upsetplot/plotting.py:797: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["edgecolor"].fillna(styles["facecolor"], inplace=True)
# /home/pihul/Desktop/Projects/Magisterka/.venv/lib64/python3.13/site-packages/upsetplot/plotting.py:798: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linestyle"].fillna("solid", inplace=True)

# %%
EN_results = [87, 54, 39, 32, 18, 17, 15, 8, 6, 5, 4, 3, 3, 2, 2, 2]
PL_results = [78, 57, 34, 32, 39, 12, 9, 3, 4, 5, 1, 6, 11, 5, 1, 0]
RU_results = [72, 43, 40, 35, 16, 14, 23, 8, 7, 25, 4, 2, 4, 3, 1, 0]

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Create 2 x 15 contingency table
table = np.array([EN_results, RU_results])
chi2_stat, p_value, dof, expected = chi2_contingency(table)
print(f"Chi-square statistic: {chi2_stat}")
print(f"Degrees of freedom: {dof}")
print(f"P-value: {p_value}")
# Out:
# Chi-square statistic: 21.188130658323438
# Degrees of freedom: 15
# P-value: 0.13092540916846754

# %%
Far_right = [149, 79, 27, 11, 10, 8, 7, 6]
Mod_conv = [52, 167, 26, 28, 6, 4, 5, 9]
Progr = [127, 79, 23, 22, 9, 8, 14, 15]
Centrist = [47, 205, 7, 7, 8, 7, 8, 8]

# %%
Polish = [78, 57, 39, 34, 32, 12, 11, 9, 6, 5, 5, 4, 3, 1, 1, 0]
Russian = [72, 43, 16, 40, 35, 14, 4, 0, 2, 3, 25, 7, 8, 4, 1, 0]
English = [87, 54, 18, 39, 32, 17, 3, 15, 3, 2, 5, 6, 8, 4, 2 ,2]
print(len(Polish), len(Russian), len(English))
# Out:
# 16 16 16

# %%
import numpy as np
from scipy.stats import chi2_contingency


# Create 2 x 15 contingency table
table = np.array([English, Polish])
chi2_stat, p_value, dof, expected = chi2_contingency(table)
print(f"Chi-square statistic: {chi2_stat}")
print(f"Degrees of freedom: {dof}")
print(f"P-value: {p_value}")
# Out:
# Chi-square statistic: 24.67657045939869
# Degrees of freedom: 15
# P-value: 0.05445923473562065

# %% [markdown]
# # Mistral

# %%
data = pd.read_parquet('data/data.parquet', engine='pyarrow')

# %%
ticks = ['Far right EN', 'Far right PL',
       'Far right RU', 'Moderate conservative EN',
       'Moderate conservative PL', 'Moderate conservative RU',
       'Progressive left EN', 'Progressive left PL',
       'Progressive left RU', 'Centrist EN',
       'Centrist PL', 'Centrist RU']
mistral_col = [col for col in data if col.startswith('Mistral')]

# %%
import seaborn as sns
sns.set_theme(rc={'figure.figsize':(11.7,8.27)})
corr = data[data['Translation_quality'] == 1.0].drop(['Translation_quality'], axis=1)[mistral_col].corr(numeric_only=True)
plot = sns.heatmap(corr, 
            xticklabels=ticks,
            yticklabels=ticks, annot=True)

plot.set_xticklabels(plot.get_xticklabels(), rotation=85)
plot.set_title('Correlation plot')
# Out:
# Text(0.5, 1.0, 'Correlation plot')

# %%
data[data['Translation_quality'] == 1.0].drop(['Translation_quality'], axis=1)[mistral_col]
# Out:
#      Mistral_far_right_EN_answer  Mistral_far_right_PL_answer  \
# 1                              1                            1
# 2                              1                            1
# 3                              1                            1
# 5                              1                            1
# 6                              0                            1
# ..                           ...                          ...
# 296                            1                            1
# 297                            0                            0
# 298                            1                            0
# 299                            0                            1
# 300                            1                            1
#
#      Mistral_far_right_RU_answer  Mistral_mod_cons_EN_answer  \
# 1                              1                           1
# 2                              1                           1
# 3                              0                           1
# 5                              0                           1
# 6                              1                           0
# ..                           ...                         ...
# 296                            1                           1
# 297                            1                           0
# 298                            1                           1
# 299                            1                           1
# 300                            1                           1
#
#      Mistral_mod_cons_PL_answer  Mistral_mod_cons_RU_answer  \
# 1                             0                           0
# 2                             0                           1
# 3                             0                           0
# 5                             0                           0
# 6                             0                           0
# ..                          ...                         ...
# 296                           0                           1
# 297                           0                           0
# 298                           0                           1
# 299                           0                           1
# 300                           0                           1
#
#      Mistral_prog_left_EN_answer  Mistral_prog_left_PL_answer  \
# 1                              1                            0
# 2                              1                            1
# 3                              1                            1
# 5                              1                            1
# 6                              1                            1
# ..                           ...                          ...
# 296                            1                            1
# 297                            0                            0
# 298                            1                            1
# 299                            1                            1
# 300                            1                            1
#
#      Mistral_prog_left_RU_answer  Mistral_centrist_EN_answer  \
# 1                              0                           1
# 2                              1                           1
# 3                              0                           1
# 5                              1                           1
# 6                              1                           0
# ..                           ...                         ...
# 296                            1                           1
# 297                            0                           0
# 298                            1                           1
# 299                            1                           1
# 300                            1                           1
#
#      Mistral_centrist_PL_answer  Mistral_centrist_RU_answer
# 1                             0                           0
# 2                             1                           0
# 3                             0                           0
# 5                             0                           0
# 6                             0                           0
# ..                          ...                         ...
# 296                           0                           1
# 297                           0                           0
# 298                           0                           0
# 299                           0                           1
# 300                           0                           1
#
# [297 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
from upsetplot import UpSet, from_indicators
df = data[data['Translation_quality'] == 1.0].drop(['Translation_quality'], axis=1)[mistral_col].iloc[:, [0, 1, 2]]
df_binary = df[df.columns.to_list()] == 1.0
df_binary.columns = ['Mistral_far_right_EN_answer', 'Mistral_far_right_PL_answer', 'Mistral_far_right_RU_answer']
upset_data = from_indicators(df_binary.columns, df_binary)

UpSet(upset_data, show_counts=True, sort_by='cardinality').plot()
plt.title("Intersections of Labels Across Pol. group for EN")
plt.show();
# Out:
# /home/pihul/Desktop/Projects/Magisterka/.venv/lib64/python3.13/site-packages/upsetplot/plotting.py:795: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linewidth"].fillna(1, inplace=True)
# /home/pihul/Desktop/Projects/Magisterka/.venv/lib64/python3.13/site-packages/upsetplot/plotting.py:796: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["facecolor"].fillna(self._facecolor, inplace=True)
# /home/pihul/Desktop/Projects/Magisterka/.venv/lib64/python3.13/site-packages/upsetplot/plotting.py:797: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["edgecolor"].fillna(styles["facecolor"], inplace=True)
# /home/pihul/Desktop/Projects/Magisterka/.venv/lib64/python3.13/site-packages/upsetplot/plotting.py:798: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linestyle"].fillna("solid", inplace=True)
